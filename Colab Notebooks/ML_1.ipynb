# %%
if __name__ == '__main__':
    n = int(input())
    arr = list(map(int, input().split()))
    iHighScore = max(arr)
    iRunnerup = -100

    for iEle in arr:
        if(iRunnerup < iEle and iHighScore > iEle):
            iRunnerup = iEle
    print(iRunnerup)
# Out:
# 4
# 57 57 -57 57
# -57

# %%
if __name__ == '__main__':
    aRecord = {}
    for _ in range(int(input())):
        name = input()
        score = float(input())
        aRecord[name] = score
    iScoreMin = float(min(aRecord.values()))
    aListKey = []
    iNewSet = False
    for (key,value) in aRecord.items():
        if float(iScoreMin) < float(value) and (iNewSet == False or float(iNewSecondLast) == float(value)):
            iNewSecondLast = float(value)
            iNewSet = True
            aListKey.append(key)

    for iEle in sorted(aListKey):
        print(iEle)
# Out:
# 5
# Prashant
# 52.22
# Kush
# 52.223
# Kant
# 52.222
# Kanti
# 52.2222
# Harshit
# 52.22222
# Kush
