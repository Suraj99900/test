# %% [markdown]
# Aim: Write a Python program to implement CNN object detection. Discuss numerous performance
# evaluation metrics for evaluating the object detecting algorithm performance.

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras import Model
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Flatten, Input

# %%
# Define the CNN model
def create_model():
 input_tensor = Input(shape=(32, 32, 3))
 x = Conv2D(32, (3, 3), activation='relu', padding='same')(input_tensor)
 x = MaxPooling2D((2, 2))(x)
 x = Conv2D(64, (3, 3), activation='relu', padding='same')(x)
 x = MaxPooling2D((2, 2))(x)
 x = Conv2D(128, (3, 3), activation='relu', padding='same')(x)
 x = MaxPooling2D((2, 2))(x)
 x = Flatten()(x)
 x = Dense(256, activation='relu')(x)
 x = Dense(1, activation='sigmoid')(x)
 model = Model(inputs=input_tensor, outputs=x)
 return model

# %%
# Load the dataset
(X_train, y_train), (X_test, y_test) = tf.keras.datasets.cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step

# %%
# Normalize the images
X_train = X_train / 255.0
X_test = X_test / 255.0

# %%
# Define the object detection labels
y_train = (y_train == 2).astype(int)
y_test = (y_test == 2).astype(int)

# %%
# Create the CNN model
model = create_model()

# %%
# Compile the model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy',tf.keras.metrics.Precision(), tf.keras.metrics.Recall()])

# %%
# Train the model
model.fit(X_train, y_train, epochs=10, batch_size=64, validation_data=(X_test, y_test))
# Out:
# Epoch 1/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 125s 155ms/step - accuracy: 0.9012 - loss: 0.2971 - precision: 0.3929 - recall: 0.0129 - val_accuracy: 0.9024 - val_loss: 0.2549 - val_precision: 0.7143 - val_recall: 0.0400
# Epoch 2/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 135s 146ms/step - accuracy: 0.9134 - loss: 0.2305 - precision: 0.6772 - recall: 0.2037 - val_accuracy: 0.9135 - val_loss: 0.2180 - val_precision: 0.7626 - val_recall: 0.1960
# Epoch 3/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 113s 145ms/step - accuracy: 0.9256 - loss: 0.1977 - precision: 0.7280 - recall: 0.3809 - val_accuracy: 0.9238 - val_loss: 0.2005 - val_precision: 0.8148 - val_recall: 0.3080
# Epoch 4/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 144s 148ms/step - accuracy: 0.9307 - loss: 0.1823 - precision: 0.7507 - recall: 0.4488 - val_accuracy: 0.9228 - val_loss: 0.2059 - val_precision: 0.6411 - val_recall: 0.5180
# Epoch 5/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 139s 144ms/step - accuracy: 0.9382 - loss: 0.1631 - precision: 0.7801 - recall: 0.5340 - val_accuracy: 0.9274 - val_loss: 0.1864 - val_precision: 0.6935 - val_recall: 0.4910
# Epoch 6/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 115s 148ms/step - accuracy: 0.9445 - loss: 0.1448 - precision: 0.8041 - recall: 0.5802 - val_accuracy: 0.9302 - val_loss: 0.1876 - val_precision: 0.6648 - val_recall: 0.6090
# Epoch 7/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 139s 143ms/step - accuracy: 0.9496 - loss: 0.1301 - precision: 0.8149 - recall: 0.6433 - val_accuracy: 0.9321 - val_loss: 0.2031 - val_precision: 0.8081 - val_recall: 0.4210
# Epoch 8/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 147s 150ms/step - accuracy: 0.9606 - loss: 0.1036 - precision: 0.8598 - recall: 0.7215 - val_accuracy: 0.9265 - val_loss: 0.1977 - val_precision: 0.6300 - val_recall: 0.6420
# Epoch 9/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 136s 142ms/step - accuracy: 0.9676 - loss: 0.0864 - precision: 0.8764 - recall: 0.7798 - val_accuracy: 0.9209 - val_loss: 0.2104 - val_precision: 0.5911 - val_recall: 0.6780
# Epoch 10/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 116s 149ms/step - accuracy: 0.9748 - loss: 0.0677 - precision: 0.9064 - recall: 0.8346 - val_accuracy: 0.9288 - val_loss: 0.2171 - val_precision: 0.6466 - val_recall: 0.6350
