# %% [markdown]
# **NLP-1-PR**

# %% [markdown]
# Survey of Recent Advances in NLP:
# Detailed survey of recent efforts being taken in the field of NLP with respect to approaches,
# applications, problems etc.

# %%
# !pip install feedparser
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.3/81.3 kB 6.4 MB/s eta 0:00:00
# ...
#   Created wheel for sgmllib3k: filename=sgmllib3k-1.0.0-py3-none-any.whl size=6046 sha256=8e963169f7d5294feb0fcaab4c35357bf1b515e9f42f4de61f46858a2ec2ea0a
#   Stored in directory: /root/.cache/pip/wheels/3b/25/2a/105d6a15df6914f4d15047691c6c28f9052cc1173e40285d03
# Successfully built sgmllib3k
# ...

# %%
import requests
import feedparser
import time

# %%
def fetch_arxiv_papers(search_query="natural language processing", max_results=20):
    base_url = "http://export.arxiv.org/api/query?"
    query = f"search_query=all:{search_query}&start=0&max_results={max_results}&sortBy=submittedDate&sortOrder=descending"

    response = requests.get(base_url + query)
    feed = feedparser.parse(response.text)

    papers = []
    for entry in feed.entries:
        paper = {
            "title": entry.title,
            "authors": [author.name for author in entry.authors],
            "summary": entry.summary,
            "published": entry.published,
            "link": entry.link
        }
        papers.append(paper)
        time.sleep(0.5)  # Respect API rate limits

    return papers

# %%
def print_papers(papers):
    for idx, paper in enumerate(papers, 1):
        print(f"\n[{idx}] {paper['title']}")
        print(f"Authors: {', '.join(paper['authors'])}")
        print(f"Published: {paper['published']}")
        print(f"Abstract: {paper['summary'][:300]}...")
        print(f"Link: {paper['link']}")

# %%
if __name__ == "__main__":
    query = "natural language processing"
    papers = fetch_arxiv_papers(search_query=query, max_results=10)
    print_papers(papers)
# Out:
# [1] Decoupled Diffusion Sparks Adaptive Scene Generation
# Authors: Yunsong Zhou, Naisheng Ye, William Ljungbergh, Tianyu Li, Jiazhi Yang, Zetong Yang, Hongzi Zhu, Christoffer Petersson, Hongyang Li
# Published: 2025-04-14T17:59:57Z
# Abstract: Controllable scene generation could reduce the cost of diverse data
# collection substantially for autonomous driving. Prior works formulate the
# traffic layout generation as predictive progress, either by denoising entire
# sequences at once or by iteratively predicting the next frame. However, full
# seq...
# Link: http://arxiv.org/abs/2504.10485v1
#
# [2] REPA-E: Unlocking VAE for End-to-End Tuning with Latent Diffusion
#   Transformers
# Authors: Xingjian Leng, Jaskirat Singh, Yunzhong Hou, Zhenchang Xing, Saining Xie, Liang Zheng
# Published: 2025-04-14T17:59:53Z
# Abstract: In this paper we tackle a fundamental question: "Can we train latent
# diffusion models together with the variational auto-encoder (VAE) tokenizer in
# ...
